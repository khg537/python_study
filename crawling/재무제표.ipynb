# %%
import requests
import bs4
import pandas as pd

# %%
my_header = {
    "referer" : "https://finance.naver.com/item/sise_day.naver?code=005930&page=1",
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Safari/537.36"
}

res = requests.get(
            "https://navercomp.wisereport.co.kr/v2/company/cF3002.aspx?cmp_cd=285130&frq=1&rpt=0&finGubun=IFRSL&frqTyp=1&cn=&encparam=MGRNWk9SQUw4NlNkazJ1bzhnbVZGZz09",
            headers = my_header
)
res
# Out:
# <Response [200]>

# %%
data_dict = res.json()

# %%
data_dict.keys()
# Out:
# dict_keys(['YYMM', 'DATA', 'FIN', 'FRQ'])

# %%
data_dict['YYMM']
# Out:
# ['2020/06<br />(IFRS연결)',
#  '2020/09<br />(IFRS연결)',
#  '2020/12<br />(IFRS연결)',
#  '2021/03<br />(IFRS연결)',
#  '2021/06<br />(IFRS연결)',
#  '2021/09(E)<br />(IFRS연결)',
#  '전분기대비<br />(QoQ)',
#  '전년동기대비<br />(YoY)',
#  '전분기대비<br />(QoQ)',
#  '전년동기대비<br />(YoY)']

# %%
data_dict['FIN']
# Out:
# 'IFRS연결'

# %%
pd.DataFrame(data_dict['DATA']).head(10)
# Out:
#   ACKIND  ACCODE                    ACC_NM  LVL  GRP_TYP  UNT_TYP P_ACCODE  \
# 0      A  200000                   매출액(수익)    1        2        2     None
# 1      A  200010                       *내수    1        1        2     None
# 2      A  200020                       *수출    1        1        2     None
# 3      A  200040                 ....제품매출액    3        0        2   200000
# 4      A  200070                 ....상품매출액    3        0        2   200000
# 5      A  200100  ....재화의판매로인한수익(상품,제품매출액)    3        0        2   200000
# 6      A  200130      ....건설계약으로인한수익(공사수익)    3        0        2   200000
# 7      A  200160                  ....분양수익    3        0        2   200000
# 8      A  200170      ....용역의제공으로인한수익(매출액)    3        0        2   200000
# 9      A  200220                 ....지분법이익    3        0        2   200000
#
#          DATA1       DATA2        DATA3  ...  DATAQ6    QOQ    YOY  \
# 0  2884.088871  3521.33136  3216.195767  ...    None  15.03  51.07
# ...
