# %%
import requests
import bs4

my_header = {
    "referer" : "https://finance.naver.com/item/sise_day.naver?code=005930&page=1",
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Safari/537.36"
}


r = requests.get(
    "https://finance.naver.com/item/sise_day.naver?code=005930&page=1", headers=my_header
    )
bs= bs4.BeautifulSoup(r.text, "lxml")
tr_elements= bs.select("table.type2 > tr[onMouseOut = 'mouseOut(this)']")

tot_data_list = []
for tr_element in tr_elements:
    data_list = []
    data= tr_element.select("td")
    for x in data:
    # print(x.text.strip())
        data_list.append(x.text.strip())
    tot_data_list.append(data_list)

# %%
tot_data_list
# Out:
# [['2021.10.08', '71,500', '100', '72,300', '72,400', '71,500', '13,969,443'],
#  ['2021.10.07', '71,600', '300', '71,600', '72,100', '71,300', '13,683,532'],
#  ['2021.10.06', '71,300', '900', '72,600', '72,800', '71,200', '18,956,962'],
#  ['2021.10.05', '72,200', '1,000', '73,000', '73,000', '71,400', '24,013,921'],
#  ['2021.10.01', '73,200', '900', '73,900', '74,000', '72,900', '15,803,395'],
#  ['2021.09.30', '74,100', '0', '74,300', '74,800', '73,700', '19,919,361'],
#  ['2021.09.29', '74,100', '2,200', '74,800', '75,300', '73,800', '23,992,458'],
#  ['2021.09.28', '76,300', '1,400', '77,700', '77,800', '76,200', '15,406,382'],
#  ['2021.09.27', '77,700', '400', '77,300', '77,700', '77,000', '11,699,798'],
#  ['2021.09.24', '77,300', '100', '77,600', '77,700', '77,100', '12,247,274']]

# %%
import requests
import bs4
import time
import random

my_header = {
    "referer" : "https://finance.naver.com/item/sise_day.naver?code=005930&page=1",
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Safari/537.36"
}

tot_data_list = []
for page_number in range(1, 5):
    r = requests.get(
        "https://finance.naver.com/item/sise_day.naver?code=005930&page={}".format(page_number), headers=my_header
        )
    bs= bs4.BeautifulSoup(r.text, "lxml")
    tr_elements= bs.select("table.type2 > tr[onMouseOut = 'mouseOut(this)']")

    
    for tr_element in tr_elements:
        data_list = []
        data= tr_element.select("td")
        for x in data:
        # print(x.text.strip())
            data_list.append(x.text.strip())
        tot_data_list.append(data_list)
        
    time.sleep(1)

# %%
len(tot_data_list)
# Out:
# 40

# %%
import pandas as pd
df = pd.DataFrame(tot_data_list, columns = ['날짜', '종가','전일비','시가','고가','저가','거래량'])

# %%
df
# Out:
#             날짜      종가    전일비      시가      고가      저가         거래량
# 0   2021.10.08  71,500    100  72,300  72,400  71,500  13,969,443
# 1   2021.10.07  71,600    300  71,600  72,100  71,300  13,683,532
# 2   2021.10.06  71,300    900  72,600  72,800  71,200  18,956,962
