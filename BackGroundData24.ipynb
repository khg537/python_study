# %%
import pandas as pd
df = pd.read_csv("./raw.csv")

# %%
df.head()
# Out:
#    No.                        Time                                  Source  \
# 0    1  2021-11-09 10:08:50.575140                                     NaN
# 1    2  2021-11-09 10:08:50.575419                                     NaN
# 2    3  2021-11-09 10:08:50.575520                2607:f8b0:4005:810::2016
# 3    4  2021-11-09 10:08:50.576057  2607:fb90:834f:9ce:192e:ded3:7f86:4cbd
# 4    5  2021-11-09 10:08:50.576298  2607:fb90:834f:9ce:192e:ded3:7f86:4cbd
#
#                               Destination Protocol  Length  \
# 0                                     NaN      SLL     105
# 1                                     NaN      SLL     142
# 2  2607:fb90:834f:9ce:192e:ded3:7f86:4cbd      UDP      90
# 3                2607:f8b0:4005:810::2016      UDP     102
# 4                2607:f8b0:4005:807::2003      UDP      97
#
#                    Info
# 0            Sent by us
# 1         Unicast to us
# 2  443  >  48611 Len=26
# 3  48611  >  443 Len=38
# 4  47832  >  443 Len=33

# %%
df1 = df[["Time","Protocol", "Info"]]

# %%
df1.head()
# Out:
#                          Time Protocol                  Info
# 0  2021-11-09 10:08:50.575140      SLL            Sent by us
# 1  2021-11-09 10:08:50.575419      SLL         Unicast to us
# 2  2021-11-09 10:08:50.575520      UDP  443  >  48611 Len=26
# 3  2021-11-09 10:08:50.576057      UDP  48611  >  443 Len=38
# 4  2021-11-09 10:08:50.576298      UDP  47832  >  443 Len=33

# %%
df1.head()
# Out:
#                          Time Protocol                  Info
# 0  2021-11-09 10:08:50.575140      SLL            Sent by us
# 1  2021-11-09 10:08:50.575419      SLL         Unicast to us
# 2  2021-11-09 10:08:50.575520      UDP  443  >  48611 Len=26
# 3  2021-11-09 10:08:50.576057      UDP  48611  >  443 Len=38
# 4  2021-11-09 10:08:50.576298      UDP  47832  >  443 Len=33

# %%
df2 = df1[df["Protocol"] == "DNS"]

# %%
df2.head()
# Out:
#                             Time Protocol  \
# 6246  2021-11-09 10:09:06.026400      DNS
# 6247  2021-11-09 10:09:06.028422      DNS
# 6262  2021-11-09 10:09:06.064394      DNS
# 6263  2021-11-09 10:09:06.064375      DNS
# 6470  2021-11-09 10:09:06.654079      DNS
#
#                                                    Info
# 6246  Standard query 0x148e AAAA trusted-collector-b...
# 6247  Standard query 0x2742 A trusted-collector-bk.t...
# 6262  Standard query response 0x148e AAAA trusted-co...
# 6263  Standard query response 0x2742 A trusted-colle...
# 6470  Standard query 0x8bb2 AAAA geller-pa.googleapi...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 522 entries, 6246 to 147507
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Time      522 non-null    object
#  1   Protocol  522 non-null    object
#  2   Info      522 non-null    object
# dtypes: object(3)
# memory usage: 16.3+ KB

# %%
df2["Time"].to_datetime()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-f765df2a1826> in <module>
# ----> 1 df2["Time"].to_datetime()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5458             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5459                 return self[name]
# -> 5460             return object.__getattribute__(self, name)
#    5461
#    5462     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'to_datetime'

# %%
df2["Time"] = pd.to_datetime(df["Time"])
# Out:
# <ipython-input-43-5c5b0c0afe12>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Time"] = pd.to_datetime(df["Time"])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 522 entries, 6246 to 147507
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Time      522 non-null    object
#  1   Protocol  522 non-null    object
#  2   Info      522 non-null    object
# dtypes: object(3)
# memory usage: 16.3+ KB

# %%
df2.head()
# Out:
#                             Time Protocol  \
# 6246  2021-11-09 10:09:06.026400      DNS
# 6247  2021-11-09 10:09:06.028422      DNS
# 6262  2021-11-09 10:09:06.064394      DNS
# 6263  2021-11-09 10:09:06.064375      DNS
# 6470  2021-11-09 10:09:06.654079      DNS
#
#                                                    Info
# 6246  Standard query 0x148e AAAA trusted-collector-b...
# 6247  Standard query 0x2742 A trusted-collector-bk.t...
# 6262  Standard query response 0x148e AAAA trusted-co...
# 6263  Standard query response 0x2742 A trusted-colle...
# 6470  Standard query 0x8bb2 AAAA geller-pa.googleapi...

# %%
df2["Time"].dt.minute
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-a37ab3cea45a> in <module>
# ----> 1 df2["Time"].dt.minute
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5454             or name in self._accessors
#    5455         ):
# -> 5456             return object.__getattribute__(self, name)
#    5457         else:
#    5458             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df2
# Out:
#                               Time Protocol  \
# 6246    2021-11-09 10:09:06.026400      DNS
# 6247    2021-11-09 10:09:06.028422      DNS
# 6262    2021-11-09 10:09:06.064394      DNS
# 6263    2021-11-09 10:09:06.064375      DNS
# 6470    2021-11-09 10:09:06.654079      DNS
# ...                            ...      ...
# 147355  2021-11-10 10:18:14.569404      DNS
# 147494  2021-11-10 10:18:15.025183      DNS
# 147495  2021-11-10 10:18:15.027449      DNS
# 147504  2021-11-10 10:18:15.066298      DNS
# 147507  2021-11-10 10:18:15.076299      DNS
#
#                                                      Info
# 6246    Standard query 0x148e AAAA trusted-collector-b...
# 6247    Standard query 0x2742 A trusted-collector-bk.t...
# 6262    Standard query response 0x148e AAAA trusted-co...
# 6263    Standard query response 0x2742 A trusted-colle...
# 6470    Standard query 0x8bb2 AAAA geller-pa.googleapi...
# ...                                                   ...
# ...

# %%
df2.index_name = "no"

# %%
df2
# Out:
#                               Time Protocol  \
# 6246    2021-11-09 10:09:06.026400      DNS
# 6247    2021-11-09 10:09:06.028422      DNS
# 6262    2021-11-09 10:09:06.064394      DNS
# 6263    2021-11-09 10:09:06.064375      DNS
# 6470    2021-11-09 10:09:06.654079      DNS
# ...                            ...      ...
# 147355  2021-11-10 10:18:14.569404      DNS
# 147494  2021-11-10 10:18:15.025183      DNS
# 147495  2021-11-10 10:18:15.027449      DNS
# 147504  2021-11-10 10:18:15.066298      DNS
# 147507  2021-11-10 10:18:15.076299      DNS
#
#                                                      Info
# 6246    Standard query 0x148e AAAA trusted-collector-b...
# 6247    Standard query 0x2742 A trusted-collector-bk.t...
# 6262    Standard query response 0x148e AAAA trusted-co...
# 6263    Standard query response 0x2742 A trusted-colle...
# 6470    Standard query 0x8bb2 AAAA geller-pa.googleapi...
# ...                                                   ...
# ...

# %%
df2
# Out:
#                               Time Protocol  \
# 6246    2021-11-09 10:09:06.026400      DNS
# 6247    2021-11-09 10:09:06.028422      DNS
# 6262    2021-11-09 10:09:06.064394      DNS
# 6263    2021-11-09 10:09:06.064375      DNS
# 6470    2021-11-09 10:09:06.654079      DNS
# ...                            ...      ...
# 147355  2021-11-10 10:18:14.569404      DNS
# 147494  2021-11-10 10:18:15.025183      DNS
# 147495  2021-11-10 10:18:15.027449      DNS
# 147504  2021-11-10 10:18:15.066298      DNS
# 147507  2021-11-10 10:18:15.076299      DNS
#
#                                                      Info
# 6246    Standard query 0x148e AAAA trusted-collector-b...
# 6247    Standard query 0x2742 A trusted-collector-bk.t...
# 6262    Standard query response 0x148e AAAA trusted-co...
# 6263    Standard query response 0x2742 A trusted-colle...
# 6470    Standard query 0x8bb2 AAAA geller-pa.googleapi...
# ...                                                   ...
# ...

# %%
df3 =df2.loc[29320:145301]

# %%
s = df3["Info"]

# %%
list=[]
list.append(s)

# %%
;

# %%
s4 = []
for s1 in s.values:
    s2 = s1.split()
    if (s2[3] == 'AAAA'):
        s3 = s2[4]
        s4.append(s3)

# %%
print(type(s3))
# Out:
# <class 'str'>

# %%
s4
# Out:
# ['cryptauthdevicesync.googleapis.com',
#  'www.googleapis.com',
#  'play-fe.googleapis.com',
#  'www.gstatic.com',
#  'play.googleapis.com',
#  'policy.ccs.mcafee.com',
#  'www.google.com',
#  'play.googleapis.com',
#  'mail.google.com',
#  'android.clients.google.com',
#  'play-fe.googleapis.com',
#  'play-lh.googleusercontent.com',
#  'connectivitycheck.gstatic.com',
#  'www.gstatic.com',
#  'dl.google.com',
#  'www.gstatic.com',
#  'www.googleapis.com',
#  'deviceintegritytokens-pa.googleapis.com',
#  'play.googleapis.com',
#  'android.googleapis.com',
#  'policy.ccs.mcafee.com',
#  'people-pa.mtls.googleapis.com',
#  'instantmessaging-pa.googleapis.com',
#  'youtubei.googleapis.com',
#  'www.youtube.com',
#  'www.googleadservices.com',
#  'www.google.com',
#  'app-measurement.com',
#  'www.lgcpm.com',
#  'play.googleapis.com',
#  'android.googleapis.com',
#  'footprints-pa.googleapis.com',
#  'play.googleapis.com',
#  'android.googleapis.com',
#  'www.googleapis.com',
# ...

# %%
s4
# Out:
# ['cryptauthdevicesync.googleapis.com',
#  'www.googleapis.com',
#  'play-fe.googleapis.com',
#  'www.gstatic.com',
#  'play.googleapis.com',
#  'policy.ccs.mcafee.com',
#  'www.google.com',
#  'play.googleapis.com',
#  'mail.google.com',
#  'android.clients.google.com',
#  'play-fe.googleapis.com',
#  'play-lh.googleusercontent.com',
#  'connectivitycheck.gstatic.com',
#  'www.gstatic.com',
#  'dl.google.com',
#  'www.gstatic.com',
#  'www.googleapis.com',
#  'deviceintegritytokens-pa.googleapis.com',
#  'play.googleapis.com',
#  'android.googleapis.com',
#  'policy.ccs.mcafee.com',
#  'people-pa.mtls.googleapis.com',
#  'instantmessaging-pa.googleapis.com',
#  'youtubei.googleapis.com',
#  'www.youtube.com',
#  'www.googleadservices.com',
#  'www.google.com',
#  'app-measurement.com',
#  'www.lgcpm.com',
#  'play.googleapis.com',
#  'android.googleapis.com',
#  'footprints-pa.googleapis.com',
#  'play.googleapis.com',
#  'android.googleapis.com',
#  'www.googleapis.com',
# ...

# %%
s5
# Out:
# {'analytics.ccs.mcafee.com',
#  'analyticsdcs.ccs.mcafee.com',
#  'android.clients.google.com',
#  'android.googleapis.com',
#  'app-measurement.com',
#  'beacons.gcp.gvt2.com',
#  'beacons.gvt2.com',
#  'brass.account.t-mobile.com',
#  'connectivitycheck.gstatic.com',
#  'cryptauthdevicesync.googleapis.com',
#  'cryptauthenrollment.googleapis.com',
#  'deviceintegritytokens-pa.googleapis.com',
#  'dl.google.com',
#  'eas3.msg.t-mobile.com',
#  'edgedl.me.gvt1.com',
#  'firebaseinstallations.googleapis.com',
#  'firebaseremoteconfig.googleapis.com',
#  'footprints-pa.googleapis.com',
#  'gnpfesdk-pa.googleapis.com',
#  'growth-pa.googleapis.com',
#  'instantmessaging-pa.googleapis.com',
#  'mail.google.com',
#  'mdh-pa.googleapis.com',
#  'path1.xtracloud.net',
#  'path2.xtracloud.net',
#  'people-pa.mtls.googleapis.com',
#  'play-fe.googleapis.com',
#  'play-lh.googleusercontent.com',
#  'play.googleapis.com',
#  'playatoms-pa.googleapis.com',
#  'policy.ccs.mcafee.com',
# ...

# %%
dir(s5)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
s5 = {}
for ele in s4:
    if s5.get(ele) == None:
        s5[ele] = 1
    else:
        s5[ele] += 1

# %%
for i, j in s5.items():
    print(i)
# Out:
# cryptauthdevicesync.googleapis.com
# www.googleapis.com
# play-fe.googleapis.com
# www.gstatic.com
# play.googleapis.com
# policy.ccs.mcafee.com
# www.google.com
# mail.google.com
# android.clients.google.com
# play-lh.googleusercontent.com
# connectivitycheck.gstatic.com
# dl.google.com
# deviceintegritytokens-pa.googleapis.com
# android.googleapis.com
# people-pa.mtls.googleapis.com
# instantmessaging-pa.googleapis.com
# youtubei.googleapis.com
# www.youtube.com
# www.googleadservices.com
# app-measurement.com
# www.lgcpm.com
# footprints-pa.googleapis.com
# analyticsdcs.ccs.mcafee.com
# analytics.ccs.mcafee.com
# mdh-pa.googleapis.com
# growth-pa.googleapis.com
# gnpfesdk-pa.googleapis.com
# playatoms-pa.googleapis.com
# beacons.gvt2.com
# r6---sn-uhvcpax0n5-x5ue.gvt1.com
# r5---sn-uhvcpax0n5-x5ue.gvt1.com
# beacons.gcp.gvt2.com
# cryptauthenrollment.googleapis.com
# update.googleapis.com
# edgedl.me.gvt1.com
# us.mcafee.com
# firebaseremoteconfig.googleapis.com
# ...

# %%
for i, j in s5.items():
    print(f'Observed {j} times during 1day test period')
# Out:
# Observed 1 times during 1day test period
# Observed 7 times during 1day test period
# Observed 5 times during 1day test period
# Observed 3 times during 1day test period
# Observed 9 times during 1day test period
# Observed 6 times during 1day test period
# Observed 5 times during 1day test period
# Observed 1 times during 1day test period
# Observed 3 times during 1day test period
# Observed 2 times during 1day test period
# Observed 4 times during 1day test period
# Observed 1 times during 1day test period
# Observed 2 times during 1day test period
# Observed 6 times during 1day test period
# Observed 1 times during 1day test period
# Observed 1 times during 1day test period
# Observed 1 times during 1day test period
# Observed 1 times during 1day test period
# Observed 1 times during 1day test period
# Observed 2 times during 1day test period
# Observed 1 times during 1day test period
# Observed 1 times during 1day test period
# Observed 3 times during 1day test period
# ...

# %%
for ele in s5.items():
    print(ele)
# Out:
# ('cryptauthdevicesync.googleapis.com', 1)
# ('www.googleapis.com', 7)
# ('play-fe.googleapis.com', 5)
# ('www.gstatic.com', 3)
# ('play.googleapis.com', 9)
# ('policy.ccs.mcafee.com', 6)
# ('www.google.com', 5)
# ('mail.google.com', 1)
# ('android.clients.google.com', 3)
# ('play-lh.googleusercontent.com', 2)
# ('connectivitycheck.gstatic.com', 4)
# ('dl.google.com', 1)
# ('deviceintegritytokens-pa.googleapis.com', 2)
# ('android.googleapis.com', 6)
# ('people-pa.mtls.googleapis.com', 1)
# ('instantmessaging-pa.googleapis.com', 1)
# ('youtubei.googleapis.com', 1)
# ('www.youtube.com', 1)
# ('www.googleadservices.com', 1)
# ('app-measurement.com', 2)
# ('www.lgcpm.com', 1)
# ('footprints-pa.googleapis.com', 1)
# ('analyticsdcs.ccs.mcafee.com', 3)
# ('analytics.ccs.mcafee.com', 2)
# ('mdh-pa.googleapis.com', 2)
# ('growth-pa.googleapis.com', 2)
# ('gnpfesdk-pa.googleapis.com', 3)
# ('playatoms-pa.googleapis.com', 1)
# ('beacons.gvt2.com', 1)
# ('r6---sn-uhvcpax0n5-x5ue.gvt1.com', 1)
# ...

# %%
len(s5)
# Out:
# 47
